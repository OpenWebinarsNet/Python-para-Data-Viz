# %%
#Boxplot
import numpy as np
import seaborn as sns
import random

# Simulación de datos
rng = np.random.RandomState(5)
variable = rng.normal(0, 1, size = 100)
random.seed(5)

grupo = random.choices(["G1", "G2", "G3"], k = 100)

grupo2 = random.choices(["A", "B"], k = 100)

df = {'variable': variable, 'grupo': grupo, 'grupo2': grupo2}

# %%
#Boxplot - Horizontal
import seaborn as sns

# Box plot
sns.boxplot(x = variable)

# Equivalente a:
sns.boxplot(x = "variable", data = df)
# Out:
# <AxesSubplot:>

# %%
#Boxplot - Vertical
import seaborn as sns

# Box plot
sns.boxplot(y = variable)
# Out:
# <AxesSubplot:>

# %%
#Color de fondo de la caja
import seaborn as sns

# Box plot
sns.boxplot(x = variable,
            color = "orange")
# Out:
# <AxesSubplot:>

# %%
#Personalizacion avanzada
import seaborn as sns

# Box plot
sns.boxplot(x = variable,
            fliersize = 10, # Tamaño de los atípicos
            linewidth = 3,  # Grosor de las líneas
            saturation = 0.95) # Saturación del color
# Out:
# <AxesSubplot:>

# %%
#Box plot por grupo
import seaborn as sns

# Box plot por grupo
sns.boxplot(x = variable,
            y = grupo)
# Out:
# <AxesSubplot:>

# %%
#Cambio de horientacion
import seaborn as sns

# Box plot por grupo
sns.boxplot(y = variable,
            x = grupo)
# Out:
# <AxesSubplot:>

# %%
#Ordenamiento
import seaborn as sns

# Box plot por grupo
sns.boxplot(y = variable,
            x = grupo,
            order = ["G1", "G2", "G3"])
# Out:
# <AxesSubplot:>

# %%
#Paleta de colores
import seaborn as sns

# Box plot por grupo
sns.boxplot(y = variable,
            x = grupo,
            palette = "Set3")
# Out:
# <AxesSubplot:>

# %%
#Box plot por grupo y subgrupo
import seaborn as sns

# Box plot por grupo
sns.boxplot(y = variable,
            x = grupo,
            hue = grupo2)
# Out:
# <AxesSubplot:>

# %%
#Violin
import seaborn as sns

sns.violinplot(x = variable)

# Equivalent to:
sns.violinplot(x = "variable", data = df)
# Out:
# <AxesSubplot:>

# %%
#Violin vertical
import seaborn as sns

sns.violinplot(y = variable)
# Out:
# <AxesSubplot:>

# %%
#Personalizacion del color
import seaborn as sns

sns.violinplot(x = variable,
               color = "green")
# Out:
# <AxesSubplot:>

# %%
#Recortar las colas de la distribución
import seaborn as sns

sns.violinplot(x = variable,
               cut = 0)
# Out:
# <AxesSubplot:>

# %%
#Grafico de violin por grupo
import seaborn as sns

sns.violinplot(x = grupo, y = variable)
# Out:
# <AxesSubplot:>

# %%
#Color por grupo
import seaborn as sns

sns.violinplot(x = grupo, y = variable,
               hue = grupo2)
# Out:
# <AxesSubplot:>

# %%
#Por ultimo personalizacion de la paleta de colores
import seaborn as sns

sns.violinplot(x = grupo, y = variable, 
               palette = "Set2")
# Out:
# <AxesSubplot:>
